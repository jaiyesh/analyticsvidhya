# %% [markdown]
# #### Jaiyesh Chahar | jaiyesh0002@gmail.com
#
# #### Data Scientist, Siemens
#
# #### Co-Founder, Petroleum From Scratch
#
# #### Linkedin: https://www.linkedin.com/in/jaiyesh-chahar-9b3642107/
#
# #### Github: https://github.com/jaiyesh
#
# #### Petroleum From Scratch Youtube Channel: https://www.youtube.com/channel/UC_lT10npISN5V32HDLAklsw

# %% [markdown]
# ## Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Lets create our own data
df = pd.DataFrame(np.random.randn(1000),index = pd.date_range('2019-06-07',periods = 1000),columns = ['value'])

# %%
df
# Out:
#                value
# 2019-06-07  1.644627
# 2019-06-08  1.036981
# 2019-06-09  1.339689
# 2019-06-10 -0.028399
# 2019-06-11  0.272766
# ...              ...
# 2022-02-26 -0.782894
# 2022-02-27 -1.494994
# 2022-02-28  0.897713
# 2022-03-01  1.779687
# 2022-03-02  0.352580
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Cumsum'] = df['value'].cumsum()

# %%
df
# Out:
#                value     Cumsum
# 2019-06-07  1.644627   1.644627
# 2019-06-08  1.036981   2.681607
# 2019-06-09  1.339689   4.021297
# 2019-06-10 -0.028399   3.992897
# 2019-06-11  0.272766   4.265663
# ...              ...        ...
# 2022-02-26 -0.782894 -34.554887
# 2022-02-27 -1.494994 -36.049881
# 2022-02-28  0.897713 -35.152167
# 2022-03-01  1.779687 -33.372480
# 2022-03-02  0.352580 -33.019900
#
# [1000 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Different subplots with figure size
df.plot(subplots = True,figsize = (15,7))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
#Different types of plots 
# Different subplots with figure size
df.plot(subplots = True,figsize = (15,7),kind = 'bar')
# Out:
# array([<AxesSubplot:title={'center':'value'}>,
#        <AxesSubplot:title={'center':'Cumsum'}>], dtype=object)

# %% [markdown]
# ### Iris Dataset

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(iris['sepal_length'],iris['sepal_width'])

# %%
#Plot Sepal length vs sepal width
plt.scatter(iris['sepal_length'],iris['sepal_width'])

# %%
#Plot Sepal length vs Petal width
plt.scatter(iris['sepal_length'],iris['petal_width'])

# %%
#Both together
plt.scatter(iris['sepal_length'],iris['sepal_width'])
plt.scatter(iris['sepal_length'],iris['petal_width'])

# %%
#Lets beautify the plots:
# give X axis Label
#give y axis Label
plt.scatter(iris['sepal_length'],iris['sepal_width'])
plt.scatter(iris['sepal_length'],iris['petal_width'])

plt.xlabel('Sepal Length',c = 'Red',size = 20)
plt.ylabel('Widths')
# Out:
# Text(0, 0.5, 'Widths')

# %%
## grids:
plt.scatter(iris['sepal_length'],iris['sepal_width'])
plt.scatter(iris['sepal_length'],iris['petal_width'])

plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)

# %%
#Adding Legend to the plot
plt.scatter(iris['sepal_length'],iris['sepal_width'],label = 'Sepal Lenght vs Sepal Width')
plt.scatter(iris['sepal_length'],iris['petal_width'],label = 'Sepal Lenght vs Petal Width')

plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend()

# %%
#Change the size of plot

plt.figure(figsize=(15,8))


plt.scatter(iris['sepal_length'],iris['sepal_width'],label = 'Sepal Lenght vs Sepal Width')
plt.scatter(iris['sepal_length'],iris['petal_width'],label = 'Sepal Lenght vs Petal Width')

plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend(loc = 'upper right')

# %%
# Change the scatter color and size

plt.figure(figsize=(16,10))


plt.scatter(iris['sepal_length'],iris['sepal_width'],label = 'Sepal Lenght vs Sepal Width',s =25,c ='blue')
plt.scatter(iris['sepal_length'],iris['petal_width'],label = 'Sepal Lenght vs Petal Width',s = 50,c='red')

plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend(loc = 'upper right')

# %%
# title
plt.figure(figsize=(16,10))


plt.scatter(iris['sepal_length'],iris['sepal_width'],label = 'Sepal Lenght vs Sepal Width',s =25,c ='blue')
plt.scatter(iris['sepal_length'],iris['petal_width'],label = 'Sepal Lenght vs Petal Width',s = 50,c='red')

plt.title('Sepal Length vs Widths')
plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend(loc = 'upper right')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#FInal step: Beautify the plot 
plt.style.use('classic')
plt.figure(figsize=(16,10))


plt.scatter(iris['sepal_length'],iris['sepal_width'],label = 'Sepal Lenght vs Sepal Width',s =25,c ='blue')
plt.scatter(iris['sepal_length'],iris['petal_width'],label = 'Sepal Lenght vs Petal Width',s = 50,c='red')

plt.title('Sepal Length vs Widths')
plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend(loc = 'upper right')

# %%
## Lets see line plot

x = np.linspace(0,4*np.pi,1000)
y = np.sin(x)
z = np.cos(x)

plt.style.use('classic')
plt.figure(figsize=(16,7))


plt.plot(x,y,label = 'Sin Function',lw=4,c ='blue')
plt.plot(x,z,label = 'Cos Function',lw=2,c='red')

plt.title('Sin and Cos')
plt.xlabel('x')
plt.ylabel('Sin and Cos')
plt.grid(True)
plt.legend(loc = 'upper right')

# %%
x = np.linspace(0,4*np.pi,1000)
y = np.sin(x)
z = np.cos(x)

plt.style.use('classic')
plt.figure(figsize=(16,7))


plt.plot(x,y,'--',label = 'Sin Function',lw=4,c ='blue')
plt.plot(x,z,label = 'Cos Function',lw=2,c='red')

plt.title('Sepal Length vs Widths')
plt.xlabel('Sepal Length')
plt.ylabel('Widths')
plt.grid(True)
plt.legend(loc = 'upper right')

# %% [markdown]
# ## histogram: how many time a number is occured

# %%
plt.hist(iris['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(iris['sepal_length'])

plt.hist(iris['petal_length'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
iris.plot(kind = 'hist',subplots = True)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
iris.plot(kind = 'hist',bins = 1000)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist',bins = 100,subplots = 'True')
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ## pie Chart

# %%
data = iris.iloc[0]

# %%
data[:-1]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
data[:-1].plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# ## box plot: statistical

# %%
plt.boxplot(iris['petal_length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a3de2f0788>,
#   <matplotlib.lines.Line2D at 0x1a3de2f0608>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a3d629f9c8>,
#   <matplotlib.lines.Line2D at 0x1a3de2f0688>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a3de2f0208>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a3de2f0848>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a3de2f0888>],
#  'means': []}

# %% [markdown]
# ## Scatter Matrix: All data comparison
#
# - Scatters for different features
# - Histogram from same feature

# %%
from pandas.plotting import scatter_matrix

# %%
pd.plotting.scatter_matrix(iris, figsize = (10,10), color = 'r', alpha = 0.9)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_width'>]],
#       dtype=object)

# %% [markdown]
# ## Dynamic plotting

# %%
from ipywidgets import interactive

# %%
def power(n,m):
    x = np.linspace(-5,5,100)
    y = x**n + m
    
    plt.figure(figsize = (7,7))
    plt.title(f'Power {n} polynomial')
    
    plt.plot(x,y,label = f'X to the power {n}')
    plt.axvline(0,c = 'black')
    
    plt.xlabel('X')
    plt.ylabel(f'X^{n}')
    plt.legend()
    plt.grid(True)
    
    return x,y

# %%
w = interactive(power,n = (0,8),m = (10,20))

# %%
w
# Out:
# interactive(children=(IntSlider(value=4, description='n', max=8), IntSlider(value=15, description='m', max=20,…

# %% [markdown]
# ## Seaborn: Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Relplot: scatter plot of seaborn

# %%
plt.style.use('fivethirtyeight')
sns.relplot(x = tips['total_bill'], y = tips['tip'])

# %%
# Hue = analyse one more variable using color
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'time')

# %%
# one more variable using style
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style = 'smoker')

# %% [markdown]
# ## countplot

# %%
sns.countplot(x = tips['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = tips['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot( y = tips['day'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %% [markdown]
# ## Categorical vs Numerical values: Catplot

# %%
sns.catplot(x = 'day', y = 'total_bill' , data = tips)

# %%
sns.catplot(x = 'smoker', y = 'total_bill' , data = tips)

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(tips['day'],tips['tip'])
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(tips['day'],tips['tip'], hue = tips['sex'])
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # JointPlot: scatter Plus histogram for bivariate

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x = tips['total_bill'], y = tips['tip'])

# %%
sns.pairplot(tips)

# %% [markdown]
# ## Fitting regression line for data points

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
# regression line based on day
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day')

# %% [markdown]
# ## Thank You
